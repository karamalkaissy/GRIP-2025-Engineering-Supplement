# %% [markdown]
# <a href="https://colab.research.google.com/github/karamalkaissy/GRIP-2025-Engineering-Supplement/blob/main/ENGR_1050_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##ENGR1050 Final Project
# By: Cooper Loveless and Karam Alkaissy

# %%
#1 is open, 2 is closed
## a=PE, b=KE, c=H, d=Q, e=W, f=m, g=goal

# Initialize variables
PE = 0
KE = 0
H = 0
Q = 0
W = 0
m = 0


##make an intro statement w print function
##cut all if negable/0 stuff bc initializing at 0
# Prompt for system type
question_1 = input("Is your system an open or closed system? (Respond with 'closed' or 'open')").strip()
if question_1 == "open":
    # Mass flow rate
    question_1f1 = input("What is the mass flow rate? (kg/s): ").strip()
    m = float(question_1f1)

    # PE
    question_1a1 = input("Is a change in PE given in the question? (Respond with 'yes' or 'no')").strip()
    if question_1a1 == "yes":
        question_1a2 = input("What is the change in PE? (J): ").strip()
        PE = float(question_1a2)

##FIX THIS: you need to ask first
    elif question_1a1 == "no":
       question_1a3 = input("Is there a change in height? (Respond with 'yes' or 'no')").strip()
       if question_1a3 == "yes":
          question_1a4 = input("What is the change in inlet/outlet height? (m)").strip()
          PE = (9.81 * float(question_1a4))

    # KE
    question_1b1 = input("Is a change in KE given in the question? (Respond with 'yes' or 'no')").strip()
    if question_1b1 == "yes":
        question_1b2 = input("What is the change in KE? (J/kg)").strip()
        KE = float(question_1b2)

    # H
    question_1c1 = input("Is a change in H given in the question? (Respond with 'yes' or 'no')").strip()
    if question_1c1 == "yes":
        question_1c2 = input("What is the change in H? (J/kg)").strip()
        H = float(question_1c2)

    # Q
    question_1d1 = input("Is a change in Q given in the question? (Respond with 'yes' or 'no')").strip()
    if question_1d1 == "yes":
        question_1d2 = input("What is the change in Q? (J/kg)").strip()
        Q = float(question_1d2)

    # W
    question_1e1 = input("Is a change in work given in the question? (Respond with 'yes' or 'no')").strip()
    if question_1e1 == "yes":
        question_1e2 = input("What is the change in work? (J/kg)").strip()
        W = float(question_1e2)
    elif question_1e1 == "no":
        question_1e3 = input("Is there a change in volume? (Respond with 'yes' or 'no')").strip()
        if question_1e3 == "yes":
            question_1e4 = input("What is the external pressure? (Pa)").strip()
            question_1e5 = input("What is the change in volume? (m^3)").strip()
            W = -(float(question_1e4) * float(question_1e5))

    # Goal
    question_1g1 = input("What are you trying to find? (Respond with 'KE', 'PE', 'H', 'Q', 'W')").strip()
    if question_1g1 == "KE":
        KE = Q + W - PE - H
        print(f"The calculated KE is: {KE} J/kg")
        solution = KE
    elif question_1g1 == "PE":
        PE = Q + W - KE - H
        print(f"The calculated PE is: {PE} J/kg")
        solution = PE
    elif question_1g1 == "H":
        H = Q + W - KE - PE
        print(f"The calculated H is: {H} J/kg")
        solution = H
    elif question_1g1 == "Q":
        Q = KE + PE + H - W
        print(f"The calculated Q is: {Q} J/kg")
        solution = Q
    elif question_1g1 == "W":
        W = KE + PE + H - Q
        print(f"The calculated W is: {W} J/kg")
        solution = W
  #convert to flow
    if question_1g1 in ["KE", "PE", "H", "Q", "W"]:
        flow = input("Should the calculated goal be in units of J/s? (Respond with 'yes' or 'no'): ").strip()
        if flow == "yes":
            flow_result = solution * m
            print(f"The result expressed in flow quantities is: {flow_result} J/s (W)")

##CLOSED SYSTEM
if question_1 == "closed":
    # Mass
    question_2f1 = input("What is the mass of the substance? (kg): ").strip()
    m = float(question_2f1)

    # PE
    question_2a1 = input("Is a change in PE given in the question? (Respond with 'yes' or 'no')").strip()
    if question_2a1 == "yes":
        question_2a2 = input("What is the change in PE? (J): ").strip()
        PE = float(question_2a2)
    elif question_2a1 == "no":
       question_2a3 = input("Is there a change in height? (Respond with 'yes' or 'no')").strip()
       if question_2a3 == "yes":
          question_2a4 = input("What is the change in inlet/outlet height? (m)").strip()
          PE = (-9.81 * float(question_2a4))

    # KE
    question_2b1 = input("Is a change in KE given in the question? (Respond with 'yes' or 'no')").strip()
    if question_2b1 == "yes":
        question_2b2 = input("What is the change in KE? (J/kg)").strip()
        KE = float(question_2b2)

    # U
    question_2c1 = input("Is a change in U given in the question? (Respond with 'yes' or 'no')").strip()
    if question_2c1 == "yes":
        question_2c2 = input("What is the change in U? (J/kg)").strip()
        U = float(question_2c2)

    # Q
    question_2d1 = input("Is a change in Q given in the question? (Respond with 'yes' or 'no')").strip()
    if question_2d1 == "yes":
        question_2d2 = input("What is the change in Q? (J/kg)").strip()
        Q = float(question_2d2)

    # W
    question_2e1 = input("Is a change in work given in the question? (Respond with 'yes' or 'no')").strip()
    if question_2e1 == "yes":
        question_2e2 = input("What is the change in work? (J/kg)").strip()
        W = float(question_2e2)
    elif question_2e1 == "no":
        question_2e3 = input("Is there a change in volume? (Respond with 'yes' or 'no')").strip()
        if question_2e3 == "yes":
            question_2e4 = input("What is the external pressure? (Pa)").strip()
            question_2e5 = input("What is the change in volume? (m^3)").strip()
            W = (-(float(question_2e4) * float(question_2e5)/m))

    # Goal
    question_2g1 = input("What are you trying to find? (Respond with 'KE', 'PE', 'U', 'Q', 'W')").strip()
    if question_2g1 == "KE":
        KE = Q + W - PE - U
        print(f"The calculated KE is: {KE} J/kg")
        solution = KE
    elif question_2g1 == "PE":
        PE = Q + W - KE - U
        print(f"The calculated PE is: {PE} J/kg")
        solution = PE
    elif question_2g1 == "U":
        U = Q + W - KE - PE
        print(f"The calculated U is: {U} J/kg")
        solution = U
    elif question_2g1 == "Q":
        Q = KE + PE + U - W
        print(f"The calculated Q is: {Q} J/kg")
        solution = Q
    elif question_2g1 == "W":
        W = KE + PE + U - Q
        print(f"The calculated W is: {W} J/kg")
        solution = W


  #convert to Jules
    if question_2g1 in ["KE", "PE", "U", "Q", "W"]:
        flow = input("Should the calculated goal be in units of Jules? (Respond with 'yes' or 'no'): ").strip()
        if flow == "yes":
            flow_result = solution * m
            print(f"The result expressed in terms of Jules is: {flow_result} J")
